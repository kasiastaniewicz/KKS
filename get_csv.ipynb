# %%
import pandas as pd

# %%
a = pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/benign_traffic.csv', error_bad_lines = False) #49548
b =pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/combo.csv', error_bad_lines = False)  #59718
c =pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/junk.csv', error_bad_lines = False)
d =pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/scan.csv', error_bad_lines = False)
e =pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/tcp.csv', error_bad_lines = False)
f =pd.read_csv('C:/Users/seeml/Desktop/danmini_doorbell/udp.csv', error_bad_lines = False)

# %%
danmini_doorbell = a.append([b,c,d,e,f],ignore_index=True)
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000       60.000000        0.000000e+00
# 1               1.000000      354.000000        0.000000e+00
# 2               1.857879      360.458980        3.578934e+01
# 3               1.000000      337.000000        0.000000e+00
# 4               1.680223      172.140917        1.848745e+04
# 5               2.604076      134.069485        1.371302e+04
# 6               3.103820      119.871020        9.719036e+03
# 7               1.031667      292.532365        1.242373e+03
# 8               1.000003       60.000654        1.555352e-01
# 9               1.899642       69.475778        8.084172e+01
# 10              2.893286       72.421986        6.933457e+01
# 11              3.892244       73.855096        5.746115e+01
# 12              4.884739       74.703637        4.849485e+01
# 13              5.884553       75.263810        4.178655e+01
# ...

# %%
danmini_doorbell.to_csv('C:/Users/seeml/Desktop/danmini_doorbell/danmini_doorbell.csv',index=False)
