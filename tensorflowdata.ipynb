# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(42)

# %%
import pandas as pd

# %%
# db_benign refers to the benign dataset of the doorbell. Other variable names follow a similar nomenclature.
db_benign = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\benign_traffic.csv", sep = ',')

# %%
db_benign.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight   ...    HpHp_L0.1_covariance  \
# 0            0.000000            1.000000   ...                     0.0
# 1            0.000000            1.000000   ...                     0.0
# 2           35.991542            1.996939   ...                     0.0
# 3            0.000000            1.000000   ...                     0.0
# 4        19153.795810            1.992323   ...                     0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        60.000000        0.000000
# 1            0.0           5.319895       344.262695        4.710446
# 2            0.0           6.318264       347.703087        9.034660
# 3            0.0           1.000000       337.000000        0.000000
# 4            0.0           1.000000        60.000000        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             60.000000           0.000000                    0.0
# 1            344.262695          22.188299                    0.0
# 2            347.703087          81.625077                    0.0
# 3            337.000000           0.000000                    0.0
# 4             60.000000           0.000000                    0.0
#
#    HpHp_L0.01_pcc    type
# 0             0.0  benign
# 1             0.0  benign
# 2             0.0  benign
# 3             0.0  benign
# 4             0.0  benign
#
# [5 rows x 116 columns]

# %%
db_benign.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count      49548.000000    49548.000000        4.954800e+04      49548.000000
# mean           2.256231       92.387127        1.989736e+01          2.288308
# std            1.453213       17.640932        3.591753e+02          1.469317
# min            1.000000       60.000000        0.000000e+00          1.000000
# 25%            1.000000       97.999999        0.000000e+00          1.000029
# 50%            1.951958      101.999737        5.410000e-08          1.984559
# 75%            3.121032      102.000000        2.594240e-04          3.398511
# max            8.837730      360.458980        2.123254e+04         10.876876
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count    49548.000000        4.954800e+04      49548.000000    49548.000000
# mean        92.382667        2.549500e+01          2.422229       92.829655
# std         17.455677        3.770187e+02          1.505076       15.858976
# min         60.000000        0.000000e+00          1.000000       60.000000
# 25%         97.976892        1.820000e-12          1.031097       93.553006
# 50%        101.985794        3.430290e-04          1.999986      101.337645
# 75%        102.000000        1.687128e-01          3.969432      101.999583
# max        360.275733        2.138792e+04         14.488665      360.091968
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight       ...        \
# count        49548.000000        49548.000000       ...
# mean            67.670150            4.291791       ...
# std            436.114015            1.644405       ...
# min              0.000000            1.000000       ...
# 25%              0.000808            2.878704       ...
# 50%              1.160150            4.241541       ...
# 75%             42.268658            5.602002       ...
# max          20362.325690           20.148226       ...
#
#        HpHp_L0.1_radius  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# count      4.954800e+04          4.954800e+04   49548.000000
# mean       8.968526e+00          1.806003e+00       0.000371
# std        2.919997e+02          7.661357e+01       0.013878
# min        0.000000e+00         -7.291934e+02      -0.142042
# 25%        4.550000e-13         -1.780000e-35       0.000000
# 50%        1.820000e-12          1.515000e-85       0.000000
# 75%        3.640000e-12          3.950000e-34       0.000000
# max        1.088123e+04          4.381892e+03       0.767997
#
#        HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# count       49548.000000     49548.000000    4.954800e+04
# mean            4.861666        92.338129    1.392164e-01
# std             1.244585        17.928385    1.812241e+00
# min             1.000000        60.000000    0.000000e+00
# 25%             4.219096        98.000000    6.740000e-07
# 50%             4.220188       102.000000    1.350000e-06
# 75%             5.308375       102.000000    1.910000e-06
# max            11.283089       354.000000    5.890428e+01
#
#        HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# count          49548.000000       4.954800e+04           4.954800e+04
# mean             130.175018       9.643987e+00           2.138594e+00
# std               25.106333       2.914718e+02           8.120645e+01
# min               60.000000       0.000000e+00          -6.899823e+02
# 25%              138.592929       1.820000e-12          -4.650000e-29
# 50%              144.249783       3.640000e-12           1.530000e-30
# 75%              144.249783       5.140000e-12           7.530000e-29
# max              688.052324       1.088186e+04           4.393551e+03
#
#        HpHp_L0.01_pcc
# count    4.954800e+04
# mean     1.775780e-03
# std      2.521668e-02
# min     -1.353522e-01
# 25%     -7.242500e-18
# 50%      0.000000e+00
# 75%      2.000000e-17
# max      7.754023e-01
#
# [8 rows x 115 columns]

# %%
pd.crosstab(db_benign.type,columns='type')
# Out:
# col_0    type
# type
# benign  49548

# %%
db_tcp = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\tcp.csv", sep = ',')
db_tcp.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       98.000000        0.000000e+00          1.000000
# 1          1.028978       98.000000        1.820000e-12          1.119465
# 2          1.361630       74.498759        1.997314e+02          1.597758
# 3          2.342684       78.127606        1.321550e+02          2.584382
# 4          1.000000       60.000000        0.000000e+00          1.000000
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       98.000000            0.000000          1.000000       98.000000
# 1       98.000000            0.000000          1.492508       98.000000
# 2       77.971939          239.774725          2.210844       83.525892
# 3       79.917496          152.993537          3.204657       83.361790
# 4       60.000000            0.000000          1.000000       60.000000
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...   HpHp_L0.1_covariance  \
# 0            0.000000            1.000000  ...                    0.0
# 1            0.000000            1.931625  ...                    0.0
# 2          253.671654            2.891647  ...                    0.0
# 3          174.573836            3.890837  ...                    0.0
# 4            0.000000            1.000000  ...                    0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        98.000000        0.000000
# 1            0.0           1.992943        98.000000        0.000001
# 2            0.0           1.000000        66.000000        0.000000
# 3            0.0           1.999972        74.500119        8.500000
# 4            0.0           1.000000        60.000000        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             98.000000       0.000000e+00                    0.0
# 1            138.592929       1.820000e-12                    0.0
# 2            116.498927       0.000000e+00                    0.0
# 3            121.516533       7.225000e+01                    0.0
# 4             60.000000       0.000000e+00                    0.0
#
#    HpHp_L0.01_pcc  type
# 0             0.0   tcp
# 1             0.0   tcp
# 2             0.0   tcp
# 3             0.0   tcp
# 4             0.0   tcp
#
# [5 rows x 116 columns]

# %%
db_tcp.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count      92141.000000    92141.000000        92141.000000      92141.000000
# mean           1.001018       60.159319           20.046651          1.001331
# std            0.068997        9.017617         1399.347316          0.076228
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%            1.000000       60.000000            0.000000          1.000000
# 75%            1.000000       60.000000            0.000000          1.000000
# max           10.717609      873.469485       157057.412000         11.058834
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count    92141.000000        92141.000000      92141.000000    92141.000000
# mean        60.157305           26.085339          1.002861       60.157100
# std          8.564671         1641.499775          0.114770        7.588280
# min         60.000000            0.000000          1.000000       60.000000
# 25%         60.000000            0.000000          1.000000       60.000000
# 50%         60.000000            0.000000          1.000000       60.000000
# 75%         60.000000            0.000000          1.000000       60.000000
# max        821.960227       164247.720100         12.209455      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight       ...        \
# count        92141.000000        92141.000000       ...
# mean            41.157560            1.020431       ...
# std           2134.781529            0.677244       ...
# min              0.000000            1.000000       ...
# 25%              0.000000            1.000000       ...
# 50%              0.000000            1.000000       ...
# 75%              0.000000            1.000000       ...
# max         159076.795300           31.355346       ...
#
#        HpHp_L0.1_radius  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# count      92141.000000          92141.000000   92141.000000
# mean          16.449205              0.117724       0.000001
# std         1357.606878             40.472744       0.000606
# min            0.000000          -2286.822799      -0.052540
# 25%            0.000000              0.000000       0.000000
# 50%            0.000000              0.000000       0.000000
# 75%            0.000000              0.000000       0.000000
# max       135415.324500          10358.123860       0.141449
#
#        HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# count       92141.000000     92141.000000    92141.000000
# mean            1.015326        60.175841        0.033690
# std             0.653330        10.228494        2.548543
# min             1.000000        60.000000        0.000000
# 25%             1.000000        60.000000        0.000000
# 50%             1.000000        60.000000        0.000000
# 75%             1.000000        60.000000        0.000000
# max            44.596940       909.000000      203.672181
#
#        HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# count          92141.000000       92141.000000           92141.000000
# mean              60.327171          31.855036               1.480368
# std               16.706273        2744.991829             187.109604
# min               60.000000           0.000000           -1017.176099
# 25%               60.000000           0.000000               0.000000
# 50%               60.000000           0.000000               0.000000
# 75%               60.000000           0.000000               0.000000
# max             1278.265351      266622.026200           39742.915500
#
#        HpHp_L0.01_pcc
# count    92141.000000
# mean         0.000015
# std          0.001860
# min         -0.011520
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.392131
#
# [8 rows x 115 columns]

# %%
pd.crosstab(db_tcp.type,columns='type')
# Out:
# col_0   type
# type
# tcp    92141

# %%
firstmerge = db_benign.merge(db_tcp)

# %%
firstmerge.head()
# Out:
# Empty DataFrame
# Columns: [MI_dir_L5_weight, MI_dir_L5_mean, MI_dir_L5_variance, MI_dir_L3_weight, MI_dir_L3_mean, MI_dir_L3_variance, MI_dir_L1_weight, MI_dir_L1_mean, MI_dir_L1_variance, MI_dir_L0.1_weight, MI_dir_L0.1_mean, MI_dir_L0.1_variance, MI_dir_L0.01_weight, MI_dir_L0.01_mean, MI_dir_L0.01_variance, H_L5_weight, H_L5_mean, H_L5_variance, H_L3_weight, H_L3_mean, H_L3_variance, H_L1_weight, H_L1_mean, H_L1_variance, H_L0.1_weight, H_L0.1_mean, H_L0.1_variance, H_L0.01_weight, H_L0.01_mean, H_L0.01_variance, HH_L5_weight, HH_L5_mean, HH_L5_std, HH_L5_magnitude, HH_L5_radius, HH_L5_covariance, HH_L5_pcc, HH_L3_weight, HH_L3_mean, HH_L3_std, HH_L3_magnitude, HH_L3_radius, HH_L3_covariance, HH_L3_pcc, HH_L1_weight, HH_L1_mean, HH_L1_std, HH_L1_magnitude, HH_L1_radius, HH_L1_covariance, HH_L1_pcc, HH_L0.1_weight, HH_L0.1_mean, HH_L0.1_std, HH_L0.1_magnitude, HH_L0.1_radius, HH_L0.1_covariance, HH_L0.1_pcc, HH_L0.01_weight, HH_L0.01_mean, HH_L0.01_std, HH_L0.01_magnitude, HH_L0.01_radius, HH_L0.01_covariance, HH_L0.01_pcc, HH_jit_L5_weight, HH_jit_L5_mean, HH_jit_L5_variance, HH_jit_L3_weight, HH_jit_L3_mean, HH_jit_L3_variance, HH_jit_L1_weight, HH_jit_L1_mean, HH_jit_L1_variance, HH_jit_L0.1_weight, HH_jit_L0.1_mean, HH_jit_L0.1_variance, HH_jit_L0.01_weight, HH_jit_L0.01_mean, HH_jit_L0.01_variance, HpHp_L5_weight, HpHp_L5_mean, HpHp_L5_std, HpHp_L5_magnitude, HpHp_L5_radius, HpHp_L5_covariance, HpHp_L5_pcc, HpHp_L3_weight, HpHp_L3_mean, HpHp_L3_std, HpHp_L3_magnitude, HpHp_L3_radius, HpHp_L3_covariance, HpHp_L3_pcc, HpHp_L1_weight, HpHp_L1_mean, HpHp_L1_std, HpHp_L1_magnitude, HpHp_L1_radius, HpHp_L1_covariance, ...]
# Index: []
#
# [0 rows x 116 columns]

# %%
trialmerge = db_benign.append([db_tcp],ignore_index=True)
trialmerge.to_csv('C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\trialmerge.csv',index=False)

# %%
trialmerge.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight   ...    HpHp_L0.1_covariance  \
# 0            0.000000            1.000000   ...                     0.0
# 1            0.000000            1.000000   ...                     0.0
# 2           35.991542            1.996939   ...                     0.0
# 3            0.000000            1.000000   ...                     0.0
# 4        19153.795810            1.992323   ...                     0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        60.000000        0.000000
# 1            0.0           5.319895       344.262695        4.710446
# 2            0.0           6.318264       347.703087        9.034660
# 3            0.0           1.000000       337.000000        0.000000
# 4            0.0           1.000000        60.000000        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             60.000000           0.000000                    0.0
# 1            344.262695          22.188299                    0.0
# 2            347.703087          81.625077                    0.0
# 3            337.000000           0.000000                    0.0
# 4             60.000000           0.000000                    0.0
#
#    HpHp_L0.01_pcc    type
# 0             0.0  benign
# 1             0.0  benign
# 2             0.0  benign
# 3             0.0  benign
# 4             0.0  benign
#
# [5 rows x 116 columns]

# %%
trialmerge.tail()
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 141684               1.0            60.0                 0.0
# 141685               1.0            60.0                 0.0
# 141686               1.0            60.0                 0.0
# 141687               1.0            60.0                 0.0
# 141688               1.0            60.0                 0.0
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 141684               1.0            60.0                 0.0
# 141685               1.0            60.0                 0.0
# 141686               1.0            60.0                 0.0
# 141687               1.0            60.0                 0.0
# 141688               1.0            60.0                 0.0
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 141684               1.0            60.0                 0.0
# 141685               1.0            60.0                 0.0
# 141686               1.0            60.0                 0.0
# 141687               1.0            60.0                 0.0
# 141688               1.0            60.0                 0.0
#
#         MI_dir_L0.1_weight  ...   HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 141684                 1.0  ...                    0.0            0.0
# 141685                 1.0  ...                    0.0            0.0
# 141686                 1.0  ...                    0.0            0.0
# 141687                 1.0  ...                    0.0            0.0
# 141688                 1.0  ...                    0.0            0.0
#
#         HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 141684                1.0             60.0             0.0
# 141685                1.0             60.0             0.0
# 141686                1.0             60.0             0.0
# 141687                1.0             60.0             0.0
# 141688                1.0             60.0             0.0
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 141684                  60.0                0.0                    0.0
# 141685                  60.0                0.0                    0.0
# 141686                  60.0                0.0                    0.0
# 141687                  60.0                0.0                    0.0
# 141688                  60.0                0.0                    0.0
#
#         HpHp_L0.01_pcc  type
# 141684             0.0   tcp
# 141685             0.0   tcp
# 141686             0.0   tcp
# 141687             0.0   tcp
# 141688             0.0   tcp
#
# [5 rows x 116 columns]

# %%
pd.crosstab(trialmerge.type,columns='type')
# Out:
# col_0    type
# type
# benign  49548
# tcp     92141

# %%
db_combo = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\combo.csv", sep = ',')
db_junk = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\junk.csv", sep = ',')
db_scan = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\scan.csv", sep = ',')
db_udp = pd.read_csv("C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\udp.csv", sep = ',')

# %%
db_merge = trialmerge.append([db_combo, db_junk, db_scan, db_udp],ignore_index=True)
db_merge.to_csv('C:\\Users\\KISHALAY\\Desktop\\tensorflow dataset\\Doorbell\\doorbellmerge.csv',index=False)

# %%
db_merge.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight   ...    HpHp_L0.1_covariance  \
# 0            0.000000            1.000000   ...                     0.0
# 1            0.000000            1.000000   ...                     0.0
# 2           35.991542            1.996939   ...                     0.0
# 3            0.000000            1.000000   ...                     0.0
# 4        19153.795810            1.992323   ...                     0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        60.000000        0.000000
# 1            0.0           5.319895       344.262695        4.710446
# 2            0.0           6.318264       347.703087        9.034660
# 3            0.0           1.000000       337.000000        0.000000
# 4            0.0           1.000000        60.000000        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             60.000000           0.000000                    0.0
# 1            344.262695          22.188299                    0.0
# 2            347.703087          81.625077                    0.0
# 3            337.000000           0.000000                    0.0
# 4             60.000000           0.000000                    0.0
#
#    HpHp_L0.01_pcc    type
# 0             0.0  benign
# 1             0.0  benign
# 2             0.0  benign
# 3             0.0  benign
# 4             0.0  benign
#
# [5 rows x 116 columns]

# %%
db_merge.tail()
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 366193               1.0            60.0                 0.0
# 366194               1.0            60.0                 0.0
# 366195               1.0            60.0                 0.0
# 366196               1.0            60.0                 0.0
# 366197               1.0            60.0                 0.0
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 366193               1.0            60.0                 0.0
# 366194               1.0            60.0                 0.0
# 366195               1.0            60.0                 0.0
# 366196               1.0            60.0                 0.0
# 366197               1.0            60.0                 0.0
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 366193               1.0            60.0                 0.0
# 366194               1.0            60.0                 0.0
# 366195               1.0            60.0                 0.0
# 366196               1.0            60.0                 0.0
# 366197               1.0            60.0                 0.0
#
#         MI_dir_L0.1_weight  ...   HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 366193                 1.0  ...                    0.0            0.0
# 366194                 1.0  ...                    0.0            0.0
# 366195                 1.0  ...                    0.0            0.0
# 366196                 1.0  ...                    0.0            0.0
# 366197                 1.0  ...                    0.0            0.0
#
#         HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 366193                1.0             60.0             0.0
# 366194                1.0             60.0             0.0
# 366195                1.0             60.0             0.0
# 366196                1.0             60.0             0.0
# 366197                1.0             60.0             0.0
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 366193                  60.0                0.0                    0.0
# 366194                  60.0                0.0                    0.0
# 366195                  60.0                0.0                    0.0
# 366196                  60.0                0.0                    0.0
# 366197                  60.0                0.0                    0.0
#
#         HpHp_L0.01_pcc  type
# 366193             0.0   udp
# 366194             0.0   udp
# 366195             0.0   udp
# 366196             0.0   udp
# 366197             0.0   udp
#
# [5 rows x 116 columns]

# %%
pd.crosstab(db_merge.type,columns='type')
# Out:
# col_0     type
# type
# benign   49548
# combo    59718
# junk     29068
# scan     29849
# tcp      92141
# udp     105874

# %%
db_merge['type'] = db_merge['type'].map({'benign': 0, 'combo': 1, 'junk': 2, 'scan': 3, 'tcp': 4, 'udp': 5})

# %%
def which(self):
    try:
        self = list(iter(self))
    except TypeError as e:
        raise Exception("""'which' method can only be applied to iterables.
        {}""".format(str(e)))
    indices = [i for i, x in enumerate(self) if bool(x) == True]
    return(indices)

# %%
legitcols=which(db_merge.apply(pd.Series.nunique) != 1)

# %%
len(legitcols)
# Out:
# 116

# %%
dataset = db_merge.values

# %%
X = dataset[:,0:115].astype(float)

# %%
Y = dataset[:,115].astype(int)

# %%
X.shape
# Out:
# (366198, 115)

# %%
from sklearn import preprocessing

# %%
X_scaled = preprocessing.scale(X)
# Out:
# C:\Users\KISHALAY\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:176: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
from sklearn.model_selection import train_test_split
db_train, db_test, y_train, y_test = sklearn.model_selection.train_test_split(X_scaled,Y, test_size = 0.25)

# %%
len(db_train)
# Out:
# 274648

# %%
len(db_test)
# Out:
# 91550

# %%
print(y_train)
# Out:
# [0. 1. 2. ... 3. 2. 4.]

# %%
np.unique(y_train)
# Out:
# array([0., 1., 2., 3., 4., 5.])

# %%
pd.crosstab(Y,columns='label')
# Out:
# col_0   label
# row_0
# 0       49548
# 1       59718
# 2       29068
# 3       29849
# 4       92141
# 5      105874
